# %% [markdown]
# Line Plot with multifacets

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

p= sns.load_dataset('dots')

#defining a color palette
pal= sns.color_palette('rocket_r')

#plot lineplot
#timeseries
sns.relplot(data=p,x='time',y='firing_rate',hue='coherence',size='choice',col='align',kind='line',size_order=["T1","T2"],palette=pal,height=5,aspect=.75,facet_kws=dict(sharex=False))

# %%
import seaborn as sns
sns.set_theme(style='ticks',palette='pastel')

p=sns.load_dataset('tips')

#Draw a nested boxplot to show bills by day and time
sns.boxplot(x='day',y='total_bill',hue='smoker',palette=["r","y"],data=p)
sns.despine(offset=10,trim=True)

# %%
import seaborn as sns
sns.set_theme(style='whitegrid')

#load 
p=sns.load_dataset('tips')

#Draw a nested violin plot and split the violins for easier comparison
sns.violinplot(data=p,x='day',y='total_bill',hue='smoker',split=True,inner='quart',linewidth=1,palette={'Yes':'b','No':'.85'})
sns.despine(left=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style='whitegrid')

d=sns.load_dataset('diamonds')

#Draw a scatterplot while assigning point colors and sizes to different variables in the dataset
f,ax=plt.subplots(figsize=(6.5,6.5))
sns.despine(f,left=True,bottom=True)
clarity_ranking=['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']
sns.scatterplot(x='carat',y='price',hue='clarity',size='depth',palette='ch:r=-.2,d=.3_r',hue_order=clarity_ranking,sizes=(1,8),linewidth=0,data=d,ax=ax)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>
